# %%
import pickle
with open('daily_patterns.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
import pandas as pd
df=pd.DataFrame(data)

# %%
len(df['state'])
# Out:
# 41115

# %%
df.columns
# Out:
# Index(['state'], dtype='object')

# %%
df['state'][2]
# Out:
# 'Vaud->Auvergne-Rhone-Alpes'

# %%
df['state'][10000]
# Out:
# 'Vaud->Valais->Vaud'

# %%
a=df['state'][1]

# %%
q=a.split('->')

# %%
q
# Out:
# ['Vaud', 'Auvergne-Rhone-Alpes']

# %%
l=[]
for s in df['state']:
    visited=s.split('->')
    l.append(visited)
    #print(s)

# %%
moves=[]
for i in l:
    for n in range(1,len(i)):
        p=[]
        if(n-1<len(i)-2):
            p.append(i[n-1])
            p.append(i[n])
            moves.append(p)

# %%
moves
# Out:
# [['Bern', 'Aargau'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['St. Gallen', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Landschaft'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Vaud', 'Zürich'],
#  ['Vaud', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Vaud', 'Zürich'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Valais', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Nidwalden'],
#  ['Nidwalden', 'Obwalden'],
#  ['Obwalden', 'Nidwalden'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Vaud', 'Genève'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Luzern'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Aargau', 'Luzern'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Basel-Stadt', 'Luzern'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Aargau', 'Luzern'],
#  ['Schaffhausen', 'Zürich'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Schwyz'],
#  ['Schwyz', 'Glarus'],
#  ['Glarus', 'St. Gallen'],
#  ['St. Gallen', 'Glarus'],
#  ['Glarus', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Schwyz', 'Zug'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Solothurn'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Graubünden', 'Ticino'],
#  ['Bern', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Jura'],
#  ['Jura', 'Bern'],
#  ['Ticino', 'Zug'],
#  ['Zug', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Appenzell Ausserrhoden'],
#  ['Appenzell Ausserrhoden', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Vaud', 'Genève'],
#  ['Obwalden', 'Nidwalden'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Vorarlberg', 'Liechtenstein'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Genève', 'Zürich'],
#  ['Zürich', 'Genève'],
#  ['Zürich', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['St. Gallen', 'Zürich'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Luzern', 'Basel-Stadt'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Zürich', 'Zug'],
#  ['Vorarlberg', 'Liechtenstein'],
#  ['Valais', 'Vaud'],
#  ['Valais', 'Vaud'],
#  ['Luzern', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Nidwalden'],
#  ['Nidwalden', 'Luzern'],
#  ['Luzern', 'Nidwalden'],
#  ['Luzern', 'Liechtenstein'],
#  ['Liechtenstein', 'Vorarlberg'],
#  ['Vorarlberg', 'Zürich'],
#  ['Zürich', 'Vorarlberg'],
#  ['Zürich', 'Solothurn'],
#  ['Solothurn', 'Fribourg'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Basel-Landschaft'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Baden-Wurttemberg', 'Schaffhausen'],
#  ['St. Gallen', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Basel-Stadt'],
#  ['Vaud', 'Neuchâtel'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Zürich'],
#  ['Zürich', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'piemonte'],
#  ['piemonte', 'lombardia'],
#  ['lombardia', 'piemonte'],
#  ['Bern', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Neuchâtel'],
#  ['Vaud', 'Neuchâtel'],
#  ['Neuchâtel', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Neuchâtel', 'Solothurn'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Basel-Stadt', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Vaud', 'Genève'],
#  ['piemonte', 'Ticino'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Luzern', 'Obwalden'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Luzern', 'Zug'],
#  ['Aargau', 'Bern'],
#  ['Aargau', 'Zürich'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Landschaft', 'Fribourg'],
#  ['Obwalden', 'Bern'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['Vaud', 'Obwalden'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Genève', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Zürich'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Vaud', 'Valais'],
#  ['Valais', 'Vaud'],
#  ['Zürich', 'Graubünden'],
#  ['Graubünden', 'Glarus'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Valais'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['St. Gallen', 'Bayern'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Thurgau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'Uri'],
#  ['Uri', 'Ticino'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Obwalden', 'Luzern'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Obwalden'],
#  ['Graubünden', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['St. Gallen', 'Bern'],
#  ['Zürich', 'Valais'],
#  ['Fribourg', 'Vaud'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Genève'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Obwalden'],
#  ['Obwalden', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Neuchâtel'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Basel-Stadt'],
#  ['Zürich', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Genève', 'Vaud'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Baden-Wurttemberg'],
#  ['Nidwalden', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'St. Gallen'],
#  ['Bern', 'Valais'],
#  ['Valais', 'Bern'],
#  ['Valais', 'Bern'],
#  ['lombardia', 'Ticino'],
#  ['lombardia', 'Ticino'],
#  ['lombardia', 'Ticino'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Aargau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ["valle d'aosta", 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Zürich'],
#  ['Genève', 'Bern'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Aargau', 'Solothurn'],
#  ['Solothurn', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Obwalden', 'Zug'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Aargau', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'Schwyz'],
#  ['Schaffhausen', 'Zürich'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Luzern'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Schaffhausen'],
#  ['Schaffhausen', 'Zürich'],
#  ['Zürich', 'Fribourg'],
#  ['Valais', 'Bern'],
#  ['Bern', 'Valais'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ['Graubünden', 'Zürich'],
#  ['Zürich', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Graubünden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Schwyz', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zug', 'Zürich'],
#  ['Obwalden', 'Nidwalden'],
#  ['Nidwalden', 'Bern'],
#  ['Bern', 'Nidwalden'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Neuchâtel'],
#  ['Jura', 'Neuchâtel'],
#  ['Neuchâtel', 'Jura'],
#  ['Jura', 'Bern'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Luzern'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Neuchâtel', 'Schaffhausen'],
#  ['Schaffhausen', 'Zürich'],
#  ['Zürich', 'Neuchâtel'],
#  ['Jura', 'Neuchâtel'],
#  ['Neuchâtel', 'Jura'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Schwyz'],
#  ['Bern', 'Solothurn'],
#  ['Bern', 'Jura'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['St. Gallen', 'Zug'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Uri'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Graubünden'],
#  ['Graubünden', 'Zürich'],
#  ['Genève', 'Vaud'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Neuchâtel', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Zürich'],
#  ['Vaud', 'Basel-Landschaft'],
#  ['Vaud', 'Zürich'],
#  ['Zürich', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ["valle d'aosta", 'Genève'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Genève', 'Vaud'],
#  ['Zürich', 'Schwyz'],
#  ['Schwyz', 'Uri'],
#  ['Zürich', 'Bern'],
#  ['Zürich', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Landschaft'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Schwyz'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'St. Gallen'],
#  ['Basel-Stadt', 'Bern'],
#  ['St. Gallen', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Vaud', 'Genève'],
#  ['Neuchâtel', 'Obwalden'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Bern'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Tirol', 'Vorarlberg'],
#  ['Vorarlberg', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Glarus', 'Graubünden'],
#  ['Graubünden', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Zürich', 'Ticino'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Bern'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Genève', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Bern'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'St. Gallen'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Genève'],
#  ['Thurgau', 'Zürich'],
#  ['Schwyz', 'Zürich'],
#  ['Valais', 'Vaud'],
#  ['Vaud', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Zürich'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Schwyz', 'Glarus'],
#  ['Zürich', 'Solothurn'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Schwyz'],
#  ['Zürich', 'Luzern'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Bern'],
#  ['Zürich', 'Aargau'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Schwyz'],
#  ['St. Gallen', 'Glarus'],
#  ['Glarus', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Schwyz'],
#  ['Schwyz', 'Ticino'],
#  ['Ticino', 'Schwyz'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'Graubünden'],
#  ['Zürich', 'Thurgau'],
#  ['Graubünden', 'Schwyz'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Valais'],
#  ['St. Gallen', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Bern', 'Neuchâtel'],
#  ['Neuchâtel', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Bayern', 'Vorarlberg'],
#  ['Vorarlberg', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Vorarlberg'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['lombardia', 'Zug'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Luzern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Solothurn'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Nidwalden'],
#  ['St. Gallen', 'Thurgau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Uri'],
#  ['Uri', 'Ticino'],
#  ['Ticino', 'Schwyz'],
#  ['Schwyz', 'Zug'],
#  ['Zürich', 'Thurgau'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Zug'],
#  ['Solothurn', 'Aargau'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Aargau'],
#  ['Aargau', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Zug'],
#  ['Solothurn', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Neuchâtel', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ...]

# %%
len(moves)
# Out:
# 54575

# %%
df.head()
# Out:
#                                                                    state
# userId year month day
# 1497   2015 9     15                                Bern->Aargau->Zürich
# 2397   2011 8     24                          Vaud->Auvergne-Rhone-Alpes
#             9     7                           Vaud->Auvergne-Rhone-Alpes
#                   14   Auvergne-Rhone-Alpes->Genève->Auvergne-Rhone-A...
#             11    7                           Vaud->Auvergne-Rhone-Alpes

# %%
df.columns
# Out:
# Index(['state'], dtype='object')

# %%
dfn=pd.DataFrame(df,columns=['userId','year','month','day','state'])

# %%
type(df.state)
# Out:
# pandas.core.series.Series

# %%
df.state
# Out:
# userId              year  month  day
# 1497                2015  9      15                                  Bern->Aargau->Zürich
# 2397                2011  8      24                            Vaud->Auvergne-Rhone-Alpes
#                           9      7                             Vaud->Auvergne-Rhone-Alpes
#                                  14     Auvergne-Rhone-Alpes->Genève->Auvergne-Rhone-A...
#                           11     7                             Vaud->Auvergne-Rhone-Alpes
#                                  28                          Genève->Auvergne-Rhone-Alpes
#                                  29                            Vaud->Auvergne-Rhone-Alpes
#                     2012  1      26                          Genève->Auvergne-Rhone-Alpes
#                                  30                          Genève->Auvergne-Rhone-Alpes
#                           2      16                          Genève->Auvergne-Rhone-Alpes
#                           3      12                          Genève->Auvergne-Rhone-Alpes
#                                  15                          Genève->Auvergne-Rhone-Alpes
#                           4      24                          Genève->Auvergne-Rhone-Alpes
#                           8      8                           Genève->Auvergne-Rhone-Alpes
#                           10     1      Auvergne-Rhone-Alpes->Genève->Auvergne-Rhone-A...
#                                  3                           Auvergne-Rhone-Alpes->Genève
#                           11     12                            Vaud->Auvergne-Rhone-Alpes
#                                  13                            Vaud->Auvergne-Rhone-Alpes
#                     2013  3      21                          Auvergne-Rhone-Alpes->Genève
#                           5      17                          Auvergne-Rhone-Alpes->Genève
#                                  27                                          Vaud->Genève
#                           6      6                                           Genève->Vaud
#                                  20                                        Zürich->Genève
#                                  24                                  Genève->Vaud->Genève
#                           10     2                                           Vaud->Genève
#                                  8                                           Bern->Genève
#                           11     6                                           Bern->Genève
#                     2014  9      17      Auvergne-Rhone-Alpes->Vaud->Auvergne-Rhone-Alpes
#                     2015  4      26                            Vaud->Auvergne-Rhone-Alpes
# 2623                2014  2      19     Baden-Wurttemberg->Basel-Stadt->Baden-Wurttemberg
#                                                               ...
# 735591222526480384  2016  5      29                                 Bern->Solothurn->Bern
#                                  30                                       Bern->Solothurn
# 736295330145275904  2016  7      5      Baden-Wurttemberg->Basel-Stadt->Baden-Wurttemberg
# 736577301689847808  2016  8      3                                         Zürich->Luzern
#                                  11                                  Bern->Fribourg->Bern
#                                  12                                     Bern->Basel-Stadt
# 736829012190826496  2016  8      5                     Neuchâtel->Bourgogne-Franche-Comte
#                                  11     Bourgogne-Franche-Comte->Neuchâtel->Bourgogne-...
# 738123588578971648  2016  8      3       Vaud->Genève->Vaud->Genève->Auvergne-Rhone-Alpes
# 738643931500564480  2016  8      8                     St. Gallen->Graubünden->St. Gallen
#                                  9                     St. Gallen->Graubünden->St. Gallen
# 739389719755247616  2016  6      15     Basel-Landschaft->Jura->Obwalden->Jura->Basel-...
#                                  16                    Bern->Jura->Bern->Vaud->Jura->Vaud
#                                  18     Genève->Vaud->Bern->Basel-Landschaft->Basel-Stadt
# 740650048724172800  2016  9      11                                          Bern->Zürich
# 741018121151123456  2016  6      16     Zürich->Basel-Stadt->Alsace-Champagne-Ardenne-...
# 742079672805134208  2016  8      6                                     Bern->Valais->Bern
# 747576901837987840  2016  7      25                         piemonte->lombardia->piemonte
# 747939256258150400  2016  6      30                                      Obwalden->Luzern
# 748234277519822848  2016  7      25     Auvergne-Rhone-Alpes->Genève->Auvergne-Rhone-A...
# 749894168919568384  2016  9      9                               Fribourg->Vaud->Fribourg
# 749894748618579840  2016  7      9                                   Vaud->Fribourg->Vaud
# 753056905614991360  2016  8      7                               Genève->Obwalden->Genève
# 760212911180681216  2016  8      4                Bern->Basel-Landschaft->Solothurn->Bern
#                                  5                         Bern->Fribourg->Vaud->Fribourg
#                                  9                                 Basel-Landschaft->Bern
# 763771254021251072  2016  9      9                                         Luzern->Zürich
#                                  10     Zürich->Aargau->Solothurn->Basel-Landschaft->B...
#                                  11                                Jura->Basel-Landschaft
# 764580268237815808  2016  8      14                    Vaud->Genève->Auvergne-Rhone-Alpes
# Name: state, dtype: object

# %%
moves
# Out:
# [['Bern', 'Aargau'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['St. Gallen', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Landschaft'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Vaud', 'Zürich'],
#  ['Vaud', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Vaud', 'Zürich'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Valais', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Auvergne-Rhone-Alpes'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Nidwalden'],
#  ['Nidwalden', 'Obwalden'],
#  ['Obwalden', 'Nidwalden'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Vaud', 'Genève'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Luzern'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Aargau', 'Luzern'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Basel-Stadt', 'Luzern'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Aargau', 'Luzern'],
#  ['Schaffhausen', 'Zürich'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Schwyz'],
#  ['Schwyz', 'Glarus'],
#  ['Glarus', 'St. Gallen'],
#  ['St. Gallen', 'Glarus'],
#  ['Glarus', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Schwyz', 'Zug'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Solothurn'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Graubünden', 'Ticino'],
#  ['Bern', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Jura'],
#  ['Jura', 'Bern'],
#  ['Ticino', 'Zug'],
#  ['Zug', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Appenzell Ausserrhoden'],
#  ['Appenzell Ausserrhoden', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Vaud', 'Genève'],
#  ['Obwalden', 'Nidwalden'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Vorarlberg', 'Liechtenstein'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Genève', 'Zürich'],
#  ['Zürich', 'Genève'],
#  ['Zürich', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['St. Gallen', 'Zürich'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Luzern', 'Basel-Stadt'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Zürich', 'Zug'],
#  ['Vorarlberg', 'Liechtenstein'],
#  ['Valais', 'Vaud'],
#  ['Valais', 'Vaud'],
#  ['Luzern', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Nidwalden'],
#  ['Nidwalden', 'Luzern'],
#  ['Luzern', 'Nidwalden'],
#  ['Luzern', 'Liechtenstein'],
#  ['Liechtenstein', 'Vorarlberg'],
#  ['Vorarlberg', 'Zürich'],
#  ['Zürich', 'Vorarlberg'],
#  ['Zürich', 'Solothurn'],
#  ['Solothurn', 'Fribourg'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Basel-Landschaft'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Baden-Wurttemberg', 'Schaffhausen'],
#  ['St. Gallen', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Basel-Stadt'],
#  ['Vaud', 'Neuchâtel'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Zürich'],
#  ['Zürich', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'piemonte'],
#  ['piemonte', 'lombardia'],
#  ['lombardia', 'piemonte'],
#  ['Bern', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Neuchâtel'],
#  ['Vaud', 'Neuchâtel'],
#  ['Neuchâtel', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Neuchâtel', 'Solothurn'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Basel-Stadt', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Vaud', 'Genève'],
#  ['piemonte', 'Ticino'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Luzern', 'Obwalden'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Luzern', 'Zug'],
#  ['Aargau', 'Bern'],
#  ['Aargau', 'Zürich'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Landschaft', 'Fribourg'],
#  ['Obwalden', 'Bern'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['Vaud', 'Obwalden'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Genève', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Zürich'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Vaud', 'Valais'],
#  ['Valais', 'Vaud'],
#  ['Zürich', 'Graubünden'],
#  ['Graubünden', 'Glarus'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Valais'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Liechtenstein'],
#  ['Liechtenstein', 'St. Gallen'],
#  ['St. Gallen', 'Bayern'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Thurgau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'Uri'],
#  ['Uri', 'Ticino'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Obwalden'],
#  ['Obwalden', 'Luzern'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Obwalden'],
#  ['Graubünden', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['St. Gallen', 'Bern'],
#  ['Zürich', 'Valais'],
#  ['Fribourg', 'Vaud'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Genève'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Zürich'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Obwalden'],
#  ['Obwalden', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Neuchâtel'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Bern', 'Neuchâtel'],
#  ['Bern', 'Basel-Stadt'],
#  ['Zürich', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Genève', 'Vaud'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Baden-Wurttemberg'],
#  ['Nidwalden', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'St. Gallen'],
#  ['Bern', 'Valais'],
#  ['Valais', 'Bern'],
#  ['Valais', 'Bern'],
#  ['lombardia', 'Ticino'],
#  ['lombardia', 'Ticino'],
#  ['lombardia', 'Ticino'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Aargau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ["valle d'aosta", 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Zürich'],
#  ['Zug', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Zürich'],
#  ['Genève', 'Bern'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Aargau', 'Solothurn'],
#  ['Solothurn', 'Genève'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Obwalden', 'Zug'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Aargau', 'St. Gallen'],
#  ['St. Gallen', 'Graubünden'],
#  ['Graubünden', 'Schwyz'],
#  ['Schaffhausen', 'Zürich'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Luzern'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Schaffhausen'],
#  ['Schaffhausen', 'Zürich'],
#  ['Zürich', 'Fribourg'],
#  ['Valais', 'Bern'],
#  ['Bern', 'Valais'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ['Graubünden', 'Zürich'],
#  ['Zürich', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Graubünden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Schwyz'],
#  ['Schwyz', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zug', 'Zürich'],
#  ['Obwalden', 'Nidwalden'],
#  ['Nidwalden', 'Bern'],
#  ['Bern', 'Nidwalden'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Neuchâtel'],
#  ['Jura', 'Neuchâtel'],
#  ['Neuchâtel', 'Jura'],
#  ['Jura', 'Bern'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Obwalden'],
#  ['Obwalden', 'Luzern'],
#  ['Luzern', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Neuchâtel', 'Schaffhausen'],
#  ['Schaffhausen', 'Zürich'],
#  ['Zürich', 'Neuchâtel'],
#  ['Jura', 'Neuchâtel'],
#  ['Neuchâtel', 'Jura'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ['Bern', 'Zürich'],
#  ['Zürich', 'Schwyz'],
#  ['Bern', 'Solothurn'],
#  ['Bern', 'Jura'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['St. Gallen', 'Zug'],
#  ['Bern', 'Luzern'],
#  ['Luzern', 'Uri'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Valais'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Fribourg'],
#  ['Bern', 'Graubünden'],
#  ['Graubünden', 'Zürich'],
#  ['Genève', 'Vaud'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Aargau'],
#  ['Bern', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Neuchâtel', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Zürich'],
#  ['Vaud', 'Basel-Landschaft'],
#  ['Vaud', 'Zürich'],
#  ['Zürich', 'Vaud'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ['Auvergne-Rhone-Alpes', 'Genève'],
#  ["valle d'aosta", 'Genève'],
#  ['Vaud', 'Bern'],
#  ['Bern', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', 'Valais'],
#  ['Genève', 'Vaud'],
#  ['Zürich', 'Schwyz'],
#  ['Schwyz', 'Uri'],
#  ['Zürich', 'Bern'],
#  ['Zürich', 'Vaud'],
#  ['Genève', 'Vaud'],
#  ['Genève', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Landschaft'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Schwyz'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'St. Gallen'],
#  ['Basel-Stadt', 'Bern'],
#  ['St. Gallen', 'Solothurn'],
#  ['Solothurn', 'Bern'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Stadt', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Obwalden'],
#  ['Obwalden', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Obwalden'],
#  ['Obwalden', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Solothurn'],
#  ['Solothurn', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Solothurn', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Stadt'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Vaud', 'Genève'],
#  ['Neuchâtel', 'Obwalden'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Fribourg'],
#  ['Vaud', 'Bern'],
#  ['Auvergne-Rhone-Alpes', 'Vaud'],
#  ['Basel-Stadt', 'Baden-Wurttemberg'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Aargau'],
#  ['Tirol', 'Vorarlberg'],
#  ['Vorarlberg', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['Glarus', 'Graubünden'],
#  ['Graubünden', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Ticino', 'Zürich'],
#  ['Zürich', 'Ticino'],
#  ['Genève', 'Auvergne-Rhone-Alpes'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Alsace-Champagne-Ardenne-Lorraine'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Bern'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Genève', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Aargau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Bern'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'St. Gallen'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Thurgau', 'Zürich'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Genève'],
#  ['Thurgau', 'Zürich'],
#  ['Schwyz', 'Zürich'],
#  ['Valais', 'Vaud'],
#  ['Vaud', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Vaud', 'Fribourg'],
#  ['Fribourg', 'Bern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Vaud', 'Genève'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Fribourg'],
#  ['Fribourg', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Zürich'],
#  ['Genève', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Genève', 'Vaud'],
#  ['Auvergne-Rhone-Alpes', "valle d'aosta"],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Alsace-Champagne-Ardenne-Lorraine', 'Basel-Stadt'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Schwyz', 'Glarus'],
#  ['Zürich', 'Solothurn'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Vaud'],
#  ['Bern', 'Valais'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Solothurn'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Schwyz'],
#  ['Zürich', 'Luzern'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Bern'],
#  ['Zürich', 'Aargau'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Schwyz'],
#  ['St. Gallen', 'Glarus'],
#  ['Glarus', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Zürich'],
#  ['St. Gallen', 'Schwyz'],
#  ['Schwyz', 'Ticino'],
#  ['Ticino', 'Schwyz'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Bern'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'Graubünden'],
#  ['Zürich', 'Thurgau'],
#  ['Graubünden', 'Schwyz'],
#  ['Zürich', 'St. Gallen'],
#  ['Zürich', 'St. Gallen'],
#  ['St. Gallen', 'Zürich'],
#  ['Zürich', 'Valais'],
#  ['St. Gallen', 'Zürich'],
#  ['Vaud', 'Genève'],
#  ['Bern', 'Neuchâtel'],
#  ['Neuchâtel', 'Bern'],
#  ['Bern', 'Neuchâtel'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Bayern', 'Vorarlberg'],
#  ['Vorarlberg', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Vorarlberg'],
#  ['Vorarlberg', 'St. Gallen'],
#  ['lombardia', 'Zug'],
#  ['Basel-Stadt', 'Zürich'],
#  ['Zürich', 'Basel-Stadt'],
#  ['Luzern', 'Vaud'],
#  ['Vaud', 'Genève'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Solothurn'],
#  ['Solothurn', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Solothurn'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Landschaft'],
#  ['Basel-Landschaft', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Zug'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Basel-Stadt', 'Aargau'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Baden-Wurttemberg', 'Thurgau'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Aargau'],
#  ['Aargau', 'Basel-Stadt'],
#  ['Zürich', 'Nidwalden'],
#  ['St. Gallen', 'Thurgau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Bern'],
#  ['Bern', 'Aargau'],
#  ['Zürich', 'Uri'],
#  ['Uri', 'Ticino'],
#  ['Ticino', 'Schwyz'],
#  ['Schwyz', 'Zug'],
#  ['Zürich', 'Thurgau'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Zug'],
#  ['Solothurn', 'Aargau'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Aargau'],
#  ['Aargau', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Luzern', 'Zug'],
#  ['Solothurn', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Luzern', 'Zug'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Zug'],
#  ['Zug', 'Luzern'],
#  ['Zürich', 'Luzern'],
#  ['Zürich', 'Thurgau'],
#  ['Thurgau', 'Baden-Wurttemberg'],
#  ['Neuchâtel', 'Zürich'],
#  ['Zürich', 'Aargau'],
#  ...]

# %%
moves_one_list=[item for sublist in moves for item in sublist]

# %%
uniques=set(moves_one_list)
uniques
# Out:
# {'Aargau',
#  'Alsace-Champagne-Ardenne-Lorraine',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'Auvergne-Rhone-Alpes',
#  'Baden-Wurttemberg',
#  'Basel-Landschaft',
#  'Basel-Stadt',
#  'Bayern',
#  'Bern',
#  'Bourgogne-Franche-Comte',
#  'Fribourg',
#  'Genève',
#  'Glarus',
#  'Graubünden',
#  'Ile-de-France',
#  'Jura',
#  'Liechtenstein',
#  'Luzern',
#  'Neuchâtel',
#  'Nidwalden',
#  'Nord-Pas-de-Calais-Picardie',
#  'Obwalden',
#  "Provence-Alpes-Cote d'Azur",
#  'Schaffhausen',
#  'Schwyz',
#  'Solothurn',
#  'St. Gallen',
#  'Thurgau',
#  'Ticino',
#  'Tirol',
#  'Uri',
#  'Valais',
#  'Vaud',
#  'Vorarlberg',
#  'Zug',
#  'Zürich',
#  'calabria',
#  'lombardia',
#  'piemonte',
#  'sardegna',
#  'trentino-alto adige/sudtirol',
#  "valle d'aosta"}

# %%
with open('api_key_geonames.txt', 'r') as in_file:
    api_key = in_file.read()

# %%
import requests

# %%
r=requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=Bern&key=AIzaSyDThRoWvI-t6Ag8OX1hhcP8BX9TG23176E')

# %%
r.json()['results'][0]
# Out:
# {'address_components': [{'long_name': 'Bern',
#    'short_name': 'Bern',
#    'types': ['locality', 'political']},
#   {'long_name': 'Bern',
#    'short_name': 'Bern',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Canton of Bern',
#    'short_name': 'BE',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Switzerland',
#    'short_name': 'CH',
#    'types': ['country', 'political']}],
#  'formatted_address': 'Bern, Switzerland',
#  'geometry': {'bounds': {'northeast': {'lat': 46.99019,
#     'lng': 7.495510099999999},
#    'southwest': {'lat': 46.9191499, 'lng': 7.294230000000001}},
#   'location': {'lat': 46.9479739, 'lng': 7.4474468},
#   'location_type': 'APPROXIMATE',
#   'viewport': {'northeast': {'lat': 46.99019, 'lng': 7.495510099999999},
#    'southwest': {'lat': 46.9191499, 'lng': 7.294230000000001}}},
#  'place_id': 'ChIJdxs61MA5jkcRmmVXBP5fVcs',
#  'types': ['locality', 'political']}

# %%
r.json()['results'][0]['geometry']['location']
# Out:
# {'lat': 46.9479739, 'lng': 7.4474468}

# %%
def geocoding_of_region(url,parameters):
    response = requests.get(url,params)
    loc=response.json()['results'][0]['geometry']['location']
    lat=loc['lat']
    lng=loc['lng']
    return lat,lng

# %%
url='https://maps.googleapis.com/maps/api/geocode/json'
params={'address':'Bern','key':api_key}
geocoding_of_region('https://maps.googleapis.com/maps/api/geocode/json',params)
# Out:
# (46.9479739, 7.4474468)

# %%
latlngs=[]
url='https://maps.googleapis.com/maps/api/geocode/json'
for reg in uniques:
    params={'address':reg,'key':api_key}
    res=geocoding_of_region(url,params)
    latlngs.append(res)

# %%
latlngs
# Out:
# [(47.44181220000001, 7.7644002),
#  (48.6616037, 9.3501336),
#  (46.9267016, 8.3849982),
#  (48.699803, 6.1878074),
#  (47.2088348, 7.532291),
#  (47.0207138, 8.652988400000002),
#  (34.0881166, 74.0339852),
#  (46.877858, 8.251249),
#  (47.2537414, 11.601487),
#  (47.3161925, 9.4316573),
#  (48.8499198, 2.6370411),
#  (45.0522366, 7.5153885),
#  (47.1661672, 8.5154946),
#  (46.9479739, 7.4474468),
#  (47.2497427, 9.9797373),
#  (45.4471431, 4.385250699999999),
#  (46.2043907, 6.1431577),
#  (46.76247499999999, 5.6729159),
#  (47.3768866, 8.541694),
#  (47.166, 9.555373),
#  (47.60378559999999, 9.0557371),
#  (46.331734, 8.800452900000002),
#  (48.7904472, 11.4978895),
#  (39.3087714, 16.3463791),
#  (46.8064773, 7.161971899999999),
#  (47.6958897, 8.6380488),
#  (46.5613135, 6.536765),
#  (46.4336662, 11.1693296),
#  (47.3876664, 8.2554295),
#  (47.366481, 9.3000916),
#  (45.7388878, 7.426186599999999),
#  (46.9899874, 6.9292732),
#  (43.9351691, 6.0679194),
#  (40.1208752, 9.012892599999999),
#  (46.1904614, 7.5449226),
#  (47.05016819999999, 8.3093072),
#  (50.2871336, 2.7812246),
#  (47.2805127, 4.9994372),
#  (46.65698709999999, 9.578025700000001),
#  (47.4244818, 9.3767173),
#  (47.0411232, 9.0679),
#  (47.5619253, 7.592767999999999),
#  (45.47906709999999, 9.8452433)]

# %%
all_unique_paths=([list(i) for i in set(map(tuple, moves))])

# %%
import numpy as np
counters=np.zeros(len(all_unique_paths))

# %%
for path in moves:
    c=0
    for i in all_unique_paths:
        if(path==i):
            counters[c]+=1
            break
        else:
            c+=1

# %%
# variable counters holds the number of appearances in this route
counters
# Out:
# array([ 15.,   3.,  60., ...,   7.,   4.,  12.])

# %%
uniques=list(uniques)

# %%
def conv_to_coordinates(path):
    p1=path[0]
    p2=path[1]
    #depart point:
    c=0
    points=[]
    for i in uniques:
        if p1==i:
            k=latlngs[c]
            points.append(k)
            break
        c+=1;
    #arrive point:
    c=0
    for i in uniques:
        if p2==i:
            k=latlngs[c]
            points.append(k)
            break
        c+=1;
            
    return points

# %%
k=conv_to_coordinates(all_unique_paths[1])
k
# Out:
# [(47.4244818, 9.3767173), (45.4471431, 4.385250699999999)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
counters=list(counters)

# %%
def add_line(path,number_of_app):
    p=conv_to_coordinates(path)
    if(number_of_app>1000):
        number_of_app=1000
    folium.PolyLine(p,color="green",weight=number_of_app*0.006, opacity=2).add_to(cantons_map)

# %%
import folium
cantons_map = folium.Map(
    location=[46.8, 8.33],
    tiles='Mapbox Bright',
    #tiles = 'Stamen Toner',
    #tiles = 'Stamen Terrain',
    zoom_start=8
)
cantons_map.choropleth(
    geo_path = '/Users/user/Desktop/epfl_semester5/data_analyis/HW3/ADA-SAF/03 - Interactive Viz/data/ch-cantons.topojson.json', 
    topojson = 'objects.cantons',
    #data=res_new1,
    #columns=['Abbreviation', 'Log amount'],
    #key_on='feature.id',
    #fill_color='BuPu'#, fill_opacity=0.7, line_opacity=0.2
    #legend_name='Grant amount in log'
)
cantons_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#adding all lines to the map
c=0
for path in all_unique_paths:
    n=counters[c]
    add_line(path,n)

# %%
cantons_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
